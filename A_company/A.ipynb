# %%
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

from pandas_profiling import ProfileReport

# %%
connect = sqlite3.connect("telecom.sqlite3")

record = pd.read_sql("select * from Record", con=connect)
clinent = pd.read_sql("select * from Client", con=connect)
record
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99998       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  mou_opkv_Mean  \
# 0              0.0          0.0        0.0     -157.25  ...      55.220000
# 1              9.1          0.0        0.0      532.25  ...     169.343333
# 2              0.0          0.0        0.0       -4.25  ...       0.233333
# 3              0.0          0.0        0.0       -1.50  ...       5.450000
# 4              0.0          0.0        0.0       38.50  ...     218.086667
# ...            ...          ...        ...         ...  ...            ...
# 99995          NaN          NaN        NaN         NaN  ...      73.316667
# 99996          NaN          NaN        NaN         NaN  ...       0.383333
# 99997          NaN          NaN        NaN         NaN  ...       0.000000
# 99998          NaN          NaN        NaN         NaN  ...     253.893333
# 99999          NaN          NaN        NaN         NaN  ...      30.746667
#
#        mou_opkd_Mean  drop_blk_Mean  attempt_Mean  complete_Mean  \
# 0                0.0       1.333333     52.333333      45.000000
# 1                0.0       9.333333    263.333333     193.333333
# 2                0.0       0.333333      9.000000       6.000000
# 3                0.0       0.000000      3.666667       3.666667
# 4                0.0      10.333333    222.333333     137.000000
# ...              ...            ...           ...            ...
# 99995            0.0       2.000000     54.666667      45.333333
# 99996            0.0       4.000000     69.333333      53.333333
# 99997            0.0       0.000000      0.000000       0.000000
# 99998            0.0      19.333333    551.000000     417.333333
# 99999            0.0       6.333333    155.666667     130.000000
#
#        callfwdv_Mean  callwait_Mean  churn  months  Customer_ID
# 0                0.0       0.333333      1      61      1000001
# 1                0.0       5.666667      0      56      1000002
# 2                0.0       0.000000      1      58      1000003
# 3                0.0       0.000000      0      60      1000004
# 4                0.0       0.000000      0      57      1000005
# ...              ...            ...    ...     ...          ...
# 99995            0.0       0.000000      1      25      1099996
# 99996            0.0       0.000000      0      27      1099997
# 99997            0.0       0.000000      0      31      1099998
# 99998            0.0       0.000000      0      25      1099999
# 99999            0.0       0.000000      1      25      1100000
#
# [100000 rows x 51 columns]

# %%
clinent
# Out:
#        uniqsubs  actvsubs new_cell crclscod asl_flag  totcalls       totmou  \
# 0             2         1        U        A        N      1652   4228.00000
# 1             1         1        N       EA        N     14654  26400.00000
# 2             1         1        Y        C        N      7903  24385.05333
# 3             1         1        Y        B        N      1502   3065.00000
# 4             1         1        Y        A        N      4485  14028.00000
# ...         ...       ...      ...      ...      ...       ...          ...
# 99995         1         1        U        B        N      3771   9534.00000
# 99996         1         1        U       CY        Y      3675   8887.00000
# 99997         1         1        U       DA        N      1271   9336.00000
# 99998         1         1        U       EA        N     10082  20784.00000
# 99999         1         1        U        B        N      1303   2355.00000
#
#         totrev   adjrev    adjmou  ...  forgntvl  ethnic  kid0_2  kid3_5  \
# 0      1504.62  1453.44   4085.00  ...       0.0       N       U       U
# 1      2851.68  2833.88  26367.00  ...       0.0       Z       U       U
# 2      2155.91  1934.47  24303.05  ...       0.0       N       U       Y
# 3      2000.90  1941.81   3035.00  ...       0.0       U       Y       U
# 4      2181.12  2166.48  13965.00  ...       0.0       I       U       U
# ...        ...      ...       ...  ...       ...     ...     ...     ...
# 99995  1594.83  1561.14   9494.00  ...       0.0       S       U       U
# 99996  1517.10  1451.85   8805.00  ...       0.0       N       U       U
# 99997  1114.91  1055.93   9234.00  ...       0.0       U       Y       Y
# 99998  2669.20  2593.26  20488.00  ...       0.0       S       U       U
# 99999   956.47   885.94   2225.00  ...       0.0       H       U       U
#
#        kid6_10  kid11_15  kid16_17  creditcd  eqpdays  Customer_ID
# 0            U         U         U         Y    361.0      1000001
# 1            U         U         U         Y    240.0      1000002
# 2            U         U         U         Y   1504.0      1000003
# 3            U         U         U         Y   1812.0      1000004
# 4            U         U         U         Y    434.0      1000005
# ...        ...       ...       ...       ...      ...          ...
# 99995        U         Y         U         Y    773.0      1099996
# 99996        Y         Y         Y         Y    835.0      1099997
# 99997        U         U         U         N    433.0      1099998
# 99998        U         U         U         N     75.0      1099999
# 99999        U         U         U         N      5.0      1100000
#
# [100000 rows x 50 columns]
